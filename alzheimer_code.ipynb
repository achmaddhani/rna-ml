# %%
import os
import time
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO
import pandas as pd
import requests
from pathlib import Path

# %%
data_dir = Path("alzheimer_data")

fastqs = list(data_dir.glob("*.fastq.gz"))
fastqs
# Out:
# [PosixPath('alzheimer_data/SRR35582354.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582355.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582360.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582361.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582370.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582371.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582359.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582358.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582367.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582366.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582363.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582362.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582357.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582356.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582369.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582368.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582364.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582365.fastq.gz'),
#  PosixPath('alzheimer_data/SRR35582372.fastq.gz')]

# %%
fastqs = [fq.resolve() for fq in fastqs]
fastqs
# Out:
# [PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582354.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582355.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582360.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582361.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582370.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582371.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582359.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582358.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582367.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582366.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582363.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582362.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582357.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582356.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582369.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582368.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582364.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582365.fastq.gz'),
#  PosixPath('/Users/achmaddhani/SCCR/regulatory_analysis_faheem/alzheimer_data/SRR35582372.fastq.gz')]

# %%
rows = []
for fq in fastqs:
    sample = fq.name.replace(".fastq.gz", "")
    rows.append({
        "sample": sample,
        "fastq_1": str(fq)
    })

df = pd.DataFrame(rows)
df
# Out:
#          sample                                            fastq_1
# 0   SRR35582354  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 1   SRR35582355  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 2   SRR35582360  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 3   SRR35582361  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 4   SRR35582370  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 5   SRR35582371  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 6   SRR35582359  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 7   SRR35582358  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 8   SRR35582367  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 9   SRR35582366  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 10  SRR35582363  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 11  SRR35582362  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 12  SRR35582357  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 13  SRR35582356  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 14  SRR35582369  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 15  SRR35582368  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 16  SRR35582364  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 17  SRR35582365  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 18  SRR35582372  /Users/achmaddhani/SCCR/regulatory_analysis_fa...

# %%
df1 = df.copy()

# %%
ad_ids = [f"SRR355823{n}" for n in range(54, 64)]      # 54–63 for AD
control_ids = [f"SRR355823{n}" for n in range(64, 73)]  # 64–72 for Control

print(f"AD_ids{ad_ids}, and control ids {control_ids}")
# Out:
# AD_ids['SRR35582354', 'SRR35582355', 'SRR35582356', 'SRR35582357', 'SRR35582358', 'SRR35582359', 'SRR35582360', 'SRR35582361', 'SRR35582362', 'SRR35582363'], and control ids ['SRR35582364', 'SRR35582365', 'SRR35582366', 'SRR35582367', 'SRR35582368', 'SRR35582369', 'SRR35582370', 'SRR35582371', 'SRR35582372']

# %%
name_map = {}

n_ad = len(ad_ids)
for i, sid in enumerate(ad_ids):
    name_map[sid] = f"ad_{n_ad - i}"

n_ctrl = len(control_ids)
for i, sid in enumerate(control_ids):
    name_map[sid] = f"control_{n_ctrl - i}"
    
print(name_map)
# Out:
# {'SRR35582354': 'ad_10', 'SRR35582355': 'ad_9', 'SRR35582356': 'ad_8', 'SRR35582357': 'ad_7', 'SRR35582358': 'ad_6', 'SRR35582359': 'ad_5', 'SRR35582360': 'ad_4', 'SRR35582361': 'ad_3', 'SRR35582362': 'ad_2', 'SRR35582363': 'ad_1', 'SRR35582364': 'control_9', 'SRR35582365': 'control_8', 'SRR35582366': 'control_7', 'SRR35582367': 'control_6', 'SRR35582368': 'control_5', 'SRR35582369': 'control_4', 'SRR35582370': 'control_3', 'SRR35582371': 'control_2', 'SRR35582372': 'control_1'}

# %%
df1["sample"] = df1["sample"].map(name_map)

# %%
df1
df1["sample"].value_counts()
# Out:
# sample
# ad_10        1
# ad_1         1
# control_8    1
# control_9    1
# control_5    1
# control_4    1
# ad_8         1
# ad_7         1
# ad_2         1
# control_7    1
# ad_9         1
# control_6    1
# ad_6         1
# ad_5         1
# control_2    1
# control_3    1
# ad_3         1
# ad_4         1
# control_1    1
# Name: count, dtype: int64

# %%
df1.sort_values(by='sample')
df1
# Out:
#        sample                                            fastq_1
# 0       ad_10  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 1        ad_9  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 2        ad_4  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 3        ad_3  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 4   control_3  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 5   control_2  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 6        ad_5  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 7        ad_6  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 8   control_6  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 9   control_7  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 10       ad_1  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 11       ad_2  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 12       ad_7  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 13       ad_8  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 14  control_4  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 15  control_5  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 16  control_9  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 17  control_8  /Users/achmaddhani/SCCR/regulatory_analysis_fa...
# 18  control_1  /Users/achmaddhani/SCCR/regulatory_analysis_fa...

# %%
df1.to_csv("samplesheet.csv", index=False)
